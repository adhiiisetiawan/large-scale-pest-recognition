# %%
from google.colab import files

files.upload() #this will prompt you to upload the kaggle.json

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d sanikamal/rock-paper-scissors-dataset

# %%
# !unzip /content/rock-paper-scissors-dataset.zip

# %%
# !git clone https://github.com/adhiiisetiawan/large-scale-pest-recognition.git

# %%
# %cd large-scale-pest-recognition

# %%
# !pip install -e .

# %%
# !ls

# %%
# !pip list

# %%
import lightning.pytorch as pl

from pest_rec.data.ip102_datamodule import IP102DataModule
from pest_rec.models.insect_pest_module import InsectPestLitModule

# %%
datamodule = IP102DataModule(
    train_dir='/content/Rock-Paper-Scissors/train',
    val_dir='/content/Rock-Paper-Scissors/test',
    test_dir='/content/Rock-Paper-Scissors/test')
datamodule.setup()

# %%
model = InsectPestLitModule(num_classes=3, freeze=True)

trainer = pl.Trainer(accelerator='gpu', devices=1, max_epochs=3)
trainer.fit(model, train_dataloaders=datamodule.train_dataloader(), val_dataloaders=datamodule.val_dataloader())
